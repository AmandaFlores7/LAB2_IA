# %% [markdown]
# Análisis exploratorio de los datos, que muestren las relaciones que existen entre los atributos y la variable que se busca predecir

# %%
# Lectura de datos de un archivo .csv
# Se importa la libreria pandas y se le asigna el alias pd
import pandas as pd
# Se lee el archivo y se asigna a la variable redWines y whiteWines
redWines = pd.read_csv('winequality-red.csv', sep=';')
whiteWines = pd.read_csv('winequality-white.csv', sep=';')

print(redWines.head(1))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5

# %%
#Analizar el dataframe con los estadisticos descriptivos de cada variable
redWines.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
#Analizar el dataframe con los estadisticos descriptivos de cada variable
whiteWines.describe().T
# Out:
#                        count        mean        std      min         25%  \
# fixed acidity         4898.0    6.854788   0.843868  3.80000    6.300000
# volatile acidity      4898.0    0.278241   0.100795  0.08000    0.210000
# citric acid           4898.0    0.334192   0.121020  0.00000    0.270000
# residual sugar        4898.0    6.391415   5.072058  0.60000    1.700000
# chlorides             4898.0    0.045772   0.021848  0.00900    0.036000
# free sulfur dioxide   4898.0   35.308085  17.007137  2.00000   23.000000
# total sulfur dioxide  4898.0  138.360657  42.498065  9.00000  108.000000
# density               4898.0    0.994027   0.002991  0.98711    0.991723
# pH                    4898.0    3.188267   0.151001  2.72000    3.090000
# sulphates             4898.0    0.489847   0.114126  0.22000    0.410000
# alcohol               4898.0   10.514267   1.230621  8.00000    9.500000
# quality               4898.0    5.877909   0.885639  3.00000    5.000000
#
# ...

# %%
#Informacion relevante del dataset redWines
redWines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#Informacion relevante del dataset whiteWines
whiteWines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# Todos los datos son numéricos, por lo que no es necesario realizar un análisis de los datos categóricos.

# %%
#Valores de la variable quality del dataset redWines
redWines['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#Valores de la variable quality del dataset whiteWines
whiteWines['quality'].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# Se puede observar que la escala de los datos para ambos van de 3 al 8 para redWine y 3 al 9 para whiteWine

# %%
#Histograma de la variable quality en ambos datasets (redWines y whiteWines)
import matplotlib.pyplot as plt
plt.hist(redWines['quality'], 10, facecolor='red', alpha=0.5, label='Red wines')
plt.hist(whiteWines['quality'], 10, facecolor='grey', alpha=0.5, label='White wines')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.title('Histogram of Quality')
plt.legend()
plt.show()

# %%
#Informacion relevante del dataset redWines en relacion a la variable quality (media, mediana, desviacion estandar, minimo, maximo)
redWines['quality'].describe()
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
#Informacion relevante del dataset whiteWines en relacion a la variable quality (media, mediana, desviacion estandar, minimo, maximo)
whiteWines['quality'].describe()
# Out:
# count    4898.000000
# mean        5.877909
# std         0.885639
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         9.000000
# Name: quality, dtype: float64

# %% [markdown]
# Comparaciones entre vino tinto y vino blanco mediante gráficos de caja

# %%
import matplotlib.pyplot as plt

# %%
#Comparacion de los Niveles de acidez fija (fixed acidity) en ambos datasets (redWines y whiteWines) mediante boxplots 
plt.boxplot([redWines['fixed acidity'], whiteWines['fixed acidity']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de acidez fija')
plt.show()

# %%
#Comparacion de los Niveles de acidez volatil (volatile acidity) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['volatile acidity'], whiteWines['volatile acidity']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de acidez volatil')
plt.show()

# %%
#Comparacion de los Niveles de acido citrico (citric acid) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['citric acid'], whiteWines['citric acid']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de acido citrico')
plt.show()

# %%
#Comparacion de los Niveles de azucar residual (residual sugar) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['residual sugar'], whiteWines['residual sugar']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de azucar residual')
plt.show()

# %%
#Comparacion de los Niveles de cloruros (chlorides) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['chlorides'], whiteWines['chlorides']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de cloruros')
plt.show()

# %%
#Comparacion de los Niveles de dioxido de azufre libre (free sulfur dioxide) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['free sulfur dioxide'], whiteWines['free sulfur dioxide']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de dioxido de azufre libre')
plt.show()

# %%
#Comparacion de los Niveles de dioxido de azufre total (total sulfur dioxide) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['total sulfur dioxide'], whiteWines['total sulfur dioxide']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de dioxido de azufre total')
plt.show()

# %%
#Comparacion de los Niveles de densidad (density) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['density'], whiteWines['density']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Densidad')
plt.show()

# %%
#Comparacion de los Niveles de los niveles de pH (pH) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['pH'], whiteWines['pH']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de pH')
plt.show()

# %%
#Comparacion de los Niveles de sulfatos (sulphates) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['sulphates'], whiteWines['sulphates']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de sulfatos')
plt.show()

# %%
#Comparacion de los Niveles de alcohol (alcohol) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['alcohol'], whiteWines['alcohol']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de alcohol')
plt.show()

# %%
#Comparacion de los Niveles de calidad (quality) en ambos datasets (redWines y whiteWines) mediante boxplots
plt.boxplot([redWines['quality'], whiteWines['quality']])
plt.xticks([1, 2], ['Tinto', 'Blanco'])
plt.ylabel('Nivel de calidad')
plt.show()

# %%
#Correlacion entre las variables del dataset redWines a través de un mapa de calor
import seaborn as sns
sns.heatmap(redWines.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
#Correlacion entre las variables del dataset redWines a través de un mapa de calor en relacion a la variable quality 
import seaborn as sns
sns.heatmap(redWines.corr()[['quality']], annot=True, cmap='RdYlGn', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# Analisando los atributos relacionados con la calidad en redWine, se puede observar que los 3 atributos con mayor correlación son alcohol, sulphates y volatile acidity.

# %%
#Correlacion entre las variables del dataset whiteWines a través de un mapa de calor
import seaborn as sns
sns.heatmap(whiteWines.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
#Correlacion entre las variables del dataset whiteWines a través de un mapa de calor en relacion a la variable quality
import seaborn as sns
sns.heatmap(whiteWines.corr()[['quality']], annot=True, cmap='RdYlGn', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# Analizanado los atributos relacionados con la calidad en whiteWine, se puede observar que los 3 atributos con mayor correlación son alcohol, density y chlorides.

# %%
#Analisis a traves de boxplot en relacion a la variable quality del dataset redWines con alcohol
sns.boxplot(x='quality', y='alcohol', data=redWines)
plt.title('Calidad y alcohol')
plt.show()

# %%
#Analisis a traves de boxplot en relacion a la variable quality del dataset redWines con sulfatos
sns.boxplot(x='quality', y='sulphates', data=redWines)
plt.title('Calidad y sulfatos')
plt.show()

# %%
#Analisis a traves de boxplot en relacion a la variable quality del dataset redWines con acidez volatil
sns.boxplot(x='quality', y='volatile acidity', data=redWines)
plt.title('Calidad y acidez volatil')
plt.show()

# %%
#Analisis a traves de boxplot en relacion a la variable quality del dataset whiteWine con alcohol
sns.boxplot(x='quality', y='alcohol', data=whiteWines)
plt.title('Calidad y alcohol')
plt.show()

# %%
#Analisis a traves de boxplot en relacion a la variable quality del dataset whiteWine con densidad
sns.boxplot(x='quality', y='density', data=whiteWines)
plt.title('Calidad y densidad')
plt.show()

# %%
#Analisis a traves de boxplot en relacion a la variable quality del dataset whiteWine con cloruros
sns.boxplot(x='quality', y='chlorides', data=whiteWines)
plt.title('Calidad y cloruros')
plt.show()
